# %%
import json
import pandas as pd
from datetime import datetime

# %%
with open('static/fear_and_greed_index.json') as f:
    data = json.load(f).get('data')

# %%
assert data

# %%
labels = data['labels']

# %%
labels[:5]
# Out:
# ['1 Feb, 2018', '2 Feb, 2018', '3 Feb, 2018', '4 Feb, 2018', '5 Feb, 2018']

# %%
values = data['datasets'][0]['data']

# %%
assert len(labels) == len(values)

# %%
dti = pd.to_datetime(labels)

# %%
ts = pd.Series(values, index=dti)

# %%
ts.head()
# Out:
# 2018-02-01    30
# 2018-02-02    15
# 2018-02-03    40
# 2018-02-04    24
# 2018-02-05    11
# dtype: int64

# %%
ts.plot(figsize=(6,9))

# %%
ts.to_csv('static/BTC-FNGI.csv')
